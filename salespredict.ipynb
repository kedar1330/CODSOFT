# %%
import pandas as pd 
import seaborn as sns 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(r"C:\Users\pooja\Downloads\advertising.csv")
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.shape
# Out:
# (200, 4)

# %%
sns.heatmap(df.corr(), square=True)
# Out:
# <Axes: >

# %%
sns.lmplot(x='TV', y='Sales', data=df)

# %%
X = df[['TV']]
y = df.Sales

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=10
)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [0.05338906]
# 7.150594888804454

# %%
model.predict([[40]])
# Out:
# C:\Users\pooja\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([9.28615737])

# %%
y_pred = model.predict(X_test)

# %%
act_predict= pd.DataFrame({
    'Actual': y_test.values.flatten(), 
    'Predict': y_pred.flatten()
})

act_predict.head(5)
# Out:
#    Actual    Predict
# 0    18.4  18.399670
# 1     7.2   7.615080
# 2    18.0  18.810766
# 3    25.5  22.291733
# 4    22.6  18.703988

# %%
act_predict.sample(10).plot(kind='bar')
# Out:
# <Axes: >

# %%
model.score(X_test, y_test)
# Out:
# 0.8288743166580129

# %%
#multiple linear regression
X = df[['TV']]
y = df.Sales

# %%
X = df[['TV', 'Radio', 'Newspaper']]
y = df.Sales

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size= 0.3, random_state = 10)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test, y_test)
# Out:
# 0.9032402609859365
